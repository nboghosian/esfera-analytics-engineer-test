# %% [markdown]
# # Analytics Engineer Test

# %% [markdown]
# ### Importando o Pandas e extraindo os arquivos CSV

# %%
# Importa o pandas e os

import pandas as pd
import os

# %%
# Define o caminho para os arquivos CSV

file_path_despesas = './input/gdv_despesas_excel.csv'
file_path_receitas = './input/gdv_receitas_excel.csv'

# %%
# Define os dataframes

df_despesas = pd.read_csv(file_path_despesas, encoding="ISO-8859-1", sep=",", engine='python', thousands=".", decimal=",") 
df_receitas = pd.read_csv(file_path_receitas, encoding="ISO-8859-1", sep=",", engine='python', thousands=".", decimal=",")

# %% [markdown]
# ### Explorando e transformando os dataframes

# %% [markdown]
# #### Limpeza e formatação

# %%
# Altera o formato de exibição dos dados numéricos para duas casas decimais, melhorando a visualização

pd.options.display.float_format = "{:.2f}".format

# %%
# Mostra o dataframe, possibilitando observar as linhas iniciais e finais de df_despesas

df_despesas
# Out:
#                                       Fonte de Recursos  \
# 0          001 - TESOURO-DOT.INICIAL E CRED.SUPLEMENTAR
# 1          001 - TESOURO-DOT.INICIAL E CRED.SUPLEMENTAR
# 2          001 - TESOURO-DOT.INICIAL E CRED.SUPLEMENTAR
# 3          001 - TESOURO-DOT.INICIAL E CRED.SUPLEMENTAR
# 4          001 - TESOURO-DOT.INICIAL E CRED.SUPLEMENTAR
# ...                                                 ...
# 2030  087 - OP.CRED.CONTR.EXTERIOR-DOT.INIC.CR.SUP-I...
# 2031  087 - OP.CRED.CONTR.EXTERIOR-DOT.INIC.CR.SUP-I...
# 2032  087 - OP.CRED.CONTR.EXTERIOR-DOT.INIC.CR.SUP-I...
# 2033  087 - OP.CRED.CONTR.EXTERIOR-DOT.INIC.CR.SUP-I...
# 2034                                                NaN
#
#                                                 Despesa       Liquidado  \
# 0     31900119 - ATRASADOS-OUTROS PODERES/MINIST.PUB...     79760504.67
# 1            31900124 - COMPLEMENTACAO DE APOSENTADORIA   1850834374.26
# 2     31900125 - COMPLEMENTACAO DE APOSENTADORIA - 1...    124536202.87
# 3                   31900325 - COMPLEMENTACAO DE PENSAO     10948297.00
# 4     31900326 - COMPLEMENTACAO DE PENSAO - 13º SALARIO       521632.30
# ...                                                 ...             ...
# 2030                             44905112 - INSTALACOES      2545097.24
# 2031         44905130 - EXECUCAO DE OBRAS E INSTALACOES     32829959.39
# 2032                       44905210 - VEICULOS DIVERSOS       755209.26
# 2033  44905234 - OUTROS EQUIPAMENTOS E MATERIAL PERM...      2098500.00
# 2034                                              TOTAL 257997692438.95
#
#       Unnamed: 3
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...          ...
# 2030         NaN
# 2031         NaN
# 2032         NaN
# 2033         NaN
# 2034         NaN
#
# [2035 rows x 4 columns]

# %%
# Mostra o dataframe, possibilitando observar as linhas iniciais e finais de df_receitas

df_receitas
# Out:
#                                      Fonte de Recursos  \
# 0         001 - TESOURO-DOT.INICIAL E CRED.SUPLEMENTAR
# 1         001 - TESOURO-DOT.INICIAL E CRED.SUPLEMENTAR
# 2         001 - TESOURO-DOT.INICIAL E CRED.SUPLEMENTAR
# 3         001 - TESOURO-DOT.INICIAL E CRED.SUPLEMENTAR
# 4         001 - TESOURO-DOT.INICIAL E CRED.SUPLEMENTAR
# ..                                                 ...
# 280           085 - RECURSOS VINCULADOS FEDERAIS-INTRA
# 281              086 - OUTRAS FONTES DE RECURSOS-INTRA
# 282  087 - OP.CRED.CONTR.EXTERIOR-DOT.INIC.CR.SUP-I...
# 283                           099 - EXTRA ORCAMENTARIA
# 284                                                NaN
#
#                                                Receita  \
# 0    11130111 - IRRF - IMP.RENDA PESSOA FISICA-PRIN...
# 1    11130311 - IRRF-IMP. RENDA RET. FTE-TRABALHO-P...
# 2         11130341 - IRRF-OUTROS RENDIMENTOS-PRINCIPAL
# 3    11180121 - IPVA - IMP. PROPR. VEIC. AUTOM  - P...
# 4                    11180122 - IPVA - MULTAS E  JUROS
# ..                                                 ...
# 280  89900011 - DEMAIS RECEITAS DE CAPITAL-PRINCIPA...
# 281  89100011 - INTEGRALIZACAO CAPITAL SOCIAL-PRINC...
# 282  89100011 - INTEGRALIZACAO CAPITAL SOCIAL-PRINC...
# 283  13210011 - REMUNERACAO  DEPOSITOS BANCARIOS - ...
# 284                                              TOTAL
#
#      Arrecadado até 02/02/2024  Unnamed: 3
# 0                4267858335.83         NaN
# 1                4323772997.93         NaN
# 2                 123071158.14         NaN
# 3                8202995933.47         NaN
# 4                      6927.39         NaN
# ..                         ...         ...
# 280                12392104.67         NaN
# 281               137377128.78         NaN
# 282                46441531.83         NaN
# 283                       0.00         NaN
# 284            257443703586.69         NaN
#
# [285 rows x 4 columns]

# %%
# Verifica os tipos de dados em df_despesas

df_despesas.dtypes
# Out:
# Fonte de Recursos     object
# Despesa               object
# Liquidado            float64
# Unnamed: 3           float64
# dtype: object

# %%
# Verifica os tipos de dados em df_receitas

df_receitas.dtypes
# Out:
# Fonte de Recursos             object
# Receita                       object
# Arrecadado até 02/02/2024    float64
# Unnamed: 3                   float64
# dtype: object

# %%
# Verifica o número de linhas e colunas dos dataframes

print( df_receitas.shape)
print( df_despesas.shape)
# Out:
# (285, 4)
# (2035, 4)

# %%
# Remove a última linha, contendo o Total, em ambos os dataframes

df_receitas_limpo = df_receitas.iloc[:-1]
df_despesas_limpo = df_despesas.iloc[:-1]

print(df_despesas_limpo.shape)
print(df_receitas_limpo.shape)
# Out:
# (2034, 4)
# (284, 4)

# %%
# Remove linhas em branco, caso existam

df_receitas_limpo = df_receitas_limpo.dropna(how='all')
df_despesas_limpo = df_despesas_limpo.dropna(how='all')

print(df_despesas_limpo.shape)
print(df_receitas_limpo.shape)
# Out:
# (2034, 4)
# (284, 4)

# %%
# Confirma se todos os valores da coluna 'Unnamed: 3' de df_despesas são nulos:

df_despesas_limpo['Unnamed: 3'].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
# Confirma se todos os valores da coluna 'Unnamed: 3' de df_receitas são nulos:

df_receitas_limpo['Unnamed: 3'].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
# Remove a colunas 'Unnamed: 3' em ambos os dataframes

df_despesas_limpo = df_despesas_limpo.drop(columns=['Unnamed: 3'])
df_receitas_limpo = df_receitas_limpo.drop(columns=['Unnamed: 3'])

# %%
# Substitui valores nulos por 0, caso existam

df_despesas_limpo = df_despesas_limpo.fillna(0)
df_receitas_limpo = df_receitas_limpo.fillna(0)

# %%
# Renomeia coluna  "Arrecadado até 02/02/2024" como "Arrecadado" e verifica as primeiras 5 linhas de df_receitas_limpo

df_receitas_limpo = df_receitas_limpo.rename(columns={'Arrecadado até 02/02/2024': 'Arrecadado'})
df_receitas_limpo.head()
# Out:
#                               Fonte de Recursos  \
# 0  001 - TESOURO-DOT.INICIAL E CRED.SUPLEMENTAR
# 1  001 - TESOURO-DOT.INICIAL E CRED.SUPLEMENTAR
# 2  001 - TESOURO-DOT.INICIAL E CRED.SUPLEMENTAR
# 3  001 - TESOURO-DOT.INICIAL E CRED.SUPLEMENTAR
# 4  001 - TESOURO-DOT.INICIAL E CRED.SUPLEMENTAR
#
#                                              Receita    Arrecadado
# 0  11130111 - IRRF - IMP.RENDA PESSOA FISICA-PRIN... 4267858335.83
# 1  11130311 - IRRF-IMP. RENDA RET. FTE-TRABALHO-P... 4323772997.93
# 2       11130341 - IRRF-OUTROS RENDIMENTOS-PRINCIPAL  123071158.14
# 3  11180121 - IPVA - IMP. PROPR. VEIC. AUTOM  - P... 8202995933.47
# 4                  11180122 - IPVA - MULTAS E  JUROS       6927.39

# %%
# Verifica as primeiras 5 linhas de df_despesas_limpo

df_despesas_limpo.head()
# Out:
#                               Fonte de Recursos  \
# 0  001 - TESOURO-DOT.INICIAL E CRED.SUPLEMENTAR
# 1  001 - TESOURO-DOT.INICIAL E CRED.SUPLEMENTAR
# 2  001 - TESOURO-DOT.INICIAL E CRED.SUPLEMENTAR
# 3  001 - TESOURO-DOT.INICIAL E CRED.SUPLEMENTAR
# 4  001 - TESOURO-DOT.INICIAL E CRED.SUPLEMENTAR
#
#                                              Despesa     Liquidado
# 0  31900119 - ATRASADOS-OUTROS PODERES/MINIST.PUB...   79760504.67
# 1         31900124 - COMPLEMENTACAO DE APOSENTADORIA 1850834374.26
# 2  31900125 - COMPLEMENTACAO DE APOSENTADORIA - 1...  124536202.87
# 3                31900325 - COMPLEMENTACAO DE PENSAO   10948297.00
# 4  31900326 - COMPLEMENTACAO DE PENSAO - 13º SALARIO     521632.30

# %% [markdown]
# #### Consolidado de valores Arrecadados e Liquidados por Fonte de Recursos

# %%
# Agrupa os dataframes por Fonte de Recursos, trazendo a soma dos valores Arrecadados e Liquidados em ordem decrescente

df_despesas_agrupado = df_despesas_limpo.groupby('Fonte de Recursos')['Liquidado'].sum().reset_index().sort_values(by='Liquidado', ascending=False).reset_index(drop=True)
df_receitas_agrupado = df_receitas_limpo.groupby('Fonte de Recursos')['Arrecadado'].sum().reset_index().sort_values(by='Arrecadado', ascending=False).reset_index(drop=True)

# %%
# Verifa as dimensões dos dataframes

print(df_despesas_agrupado.shape)
print(df_receitas_agrupado.shape)
# Out:
# (20, 2)
# (21, 2)

# %%
# Traz o total arrecadado e liquidado por Fonte de Recursos, realizando um left join de df_receitas
# utilizado Fonte de Recursos como chave

df_consolidado = pd.merge(df_receitas_agrupado, df_despesas_agrupado[['Fonte de Recursos', 'Liquidado']], 
                     how='left', on='Fonte de Recursos').fillna(0)

# %%
# Cria a coluna Variação, que subtrai o valor Liquidado do Arrecadado

df_consolidado['Variação'] = df_consolidado['Arrecadado'] - df_consolidado['Liquidado']
df_consolidado
# Out:
#                                     Fonte de Recursos      Arrecadado  \
# 0        001 - TESOURO-DOT.INICIAL E CRED.SUPLEMENTAR 145359336941.22
# 1                 002 - RECURSOS VINCULADOS ESTADUAIS  51838245153.90
# 2   081 - TESOURO-DOT.INICIAL E CRED.SUPLEMENTAR-I...  30947501477.57
# 3        004 - REC.PROPRIO-ADM.IND.-DOT.INIC.CR.SUPL.  10879120172.16
# 4                  005 - RECURSOS VINCULADOS FEDERAIS   8585540905.79
# 5   003 - RECURSOS VINCULADOS-FUNDO ESPECIAL DE DE...   5443588925.19
# 6   007 - OP.CRED.E CONTRIB.DO EXTERIOR-DOT.INIC.C...   2382563194.35
# 7                     006 - OUTRAS FONTES DE RECURSOS   1091691526.65
# 8           082 - RECURSOS VINCULADOS ESTADUAIS-INTRA    406170287.52
# 9            085 - RECURSOS VINCULADOS FEDERAIS-INTRA    225804440.89
# 10              086 - OUTRAS FONTES DE RECURSOS-INTRA    137377128.78
# 11  083 - RECURSOS VINCULADOS-FUNDO ESP. DESPESA-I...     47742989.03
# 12  047 - REC.OPERAC. DE CREDITO-P/SUPERAVIT FINAN...     47621267.18
# 13  087 - OP.CRED.CONTR.EXTERIOR-DOT.INIC.CR.SUP-I...     46441531.83
# 14  084 - REC.PROPRIO-ADM.IND.-DOT.INIC.CR.SUPL.-I...      4376295.11
# 15  044 - REC.PROP.ADM.IND-CRED.P/SUPERVAVIT FINAN...       575864.80
# 16  042 - REC.VINC.ESTADUAIS-CRED.SUPERAVIT FINANC...         5354.08
# 17    045 - REC.VINC.TRANSF.FEDERAL/SUPERAVIT FINANC.          130.63
# 18   041 - TESOURO - CREDITO POR SUPERAVIT FINANCEIRO            0.01
# 19     043 - F.E.D - CREDITO POR SUPERAVIT FINANCEIRO            0.00
# 20                           099 - EXTRA ORCAMENTARIA            0.00
#
#          Liquidado       Variação
# 0  146622207006.13 -1262870064.91
# 1   51132135649.47   706109504.43
# 2   30931190214.98    16311262.59
# 3   10198168865.47   680951306.69
# 4    8091074605.92   494466299.87
# 5    4364160481.91  1079428443.28
# 6    1513684017.05   868879177.30
# 7     615464247.96   476227278.69
# 8     406170287.52           0.00
# 9     225804440.89           0.00
# 10    137377128.78           0.00
# 11     46996087.83      746901.20
# 12    892962257.01  -845340989.83
# 13     46441531.83           0.00
# 14      2743393.65     1632901.46
# 15    472070029.65  -471494164.85
# 16    524395868.66  -524390514.58
# 17    326178008.96  -326177878.33
# 18   1417328404.57 -1417328404.56
# 19     31139910.71   -31139910.71
# 20            0.00           0.00

# %% [markdown]
# #### Dataframe único, com as informações detalhadas de Despesas e Receitas

# %%
# Cria coluna Tipo, a fim de identificar a linha como Despesa ou Receita

df_despesas_alterado = df_despesas_limpo
df_receitas_alterado = df_receitas_limpo

df_despesas_alterado['Tipo'] = 'Despesa/Liquidado'
df_receitas_alterado['Tipo'] = 'Receita/Arrecadado'

# %%
# Renomeia as colunas

df_despesas_alterado.rename(columns={'Despesa': 'Descrição', 'Liquidado': 'Valor'}, inplace=True)
df_receitas_alterado.rename(columns={'Receita': 'Descrição', 'Arrecadado': 'Valor'}, inplace=True)

# %%
# Combina os dataframes em df_combinado

df_combinado = pd.concat([df_receitas_alterado, df_despesas_alterado], axis=0)
df_combinado.reset_index(drop=True, inplace=True)

# %%
# Reordena as colunas do dataframe resultante

ordem = ['Fonte de Recursos', 'Tipo', 'Descrição', 'Valor']
df_combinado = df_combinado[ordem]
df_combinado
# Out:
#                                       Fonte de Recursos                Tipo  \
# 0          001 - TESOURO-DOT.INICIAL E CRED.SUPLEMENTAR  Receita/Arrecadado
# 1          001 - TESOURO-DOT.INICIAL E CRED.SUPLEMENTAR  Receita/Arrecadado
# 2          001 - TESOURO-DOT.INICIAL E CRED.SUPLEMENTAR  Receita/Arrecadado
# 3          001 - TESOURO-DOT.INICIAL E CRED.SUPLEMENTAR  Receita/Arrecadado
# 4          001 - TESOURO-DOT.INICIAL E CRED.SUPLEMENTAR  Receita/Arrecadado
# ...                                                 ...                 ...
# 2313  087 - OP.CRED.CONTR.EXTERIOR-DOT.INIC.CR.SUP-I...   Despesa/Liquidado
# 2314  087 - OP.CRED.CONTR.EXTERIOR-DOT.INIC.CR.SUP-I...   Despesa/Liquidado
# 2315  087 - OP.CRED.CONTR.EXTERIOR-DOT.INIC.CR.SUP-I...   Despesa/Liquidado
# 2316  087 - OP.CRED.CONTR.EXTERIOR-DOT.INIC.CR.SUP-I...   Despesa/Liquidado
# 2317  087 - OP.CRED.CONTR.EXTERIOR-DOT.INIC.CR.SUP-I...   Despesa/Liquidado
#
#                                               Descrição         Valor
# 0     11130111 - IRRF - IMP.RENDA PESSOA FISICA-PRIN... 4267858335.83
# 1     11130311 - IRRF-IMP. RENDA RET. FTE-TRABALHO-P... 4323772997.93
# 2          11130341 - IRRF-OUTROS RENDIMENTOS-PRINCIPAL  123071158.14
# 3     11180121 - IPVA - IMP. PROPR. VEIC. AUTOM  - P... 8202995933.47
# 4                     11180122 - IPVA - MULTAS E  JUROS       6927.39
# ...                                                 ...           ...
# 2313                  44905111 - GERENCIAMENTO DE OBRAS    8150057.66
# 2314                             44905112 - INSTALACOES    2545097.24
# 2315         44905130 - EXECUCAO DE OBRAS E INSTALACOES   32829959.39
# 2316                       44905210 - VEICULOS DIVERSOS     755209.26
# 2317  44905234 - OUTROS EQUIPAMENTOS E MATERIAL PERM...    2098500.00
#
# [2318 rows x 4 columns]

# %% [markdown]
# ### Exportando os dataframes

# %%
# Cria diretório output, caso não exista, e exporta os dataframes como arquivos CSV

directory = "output"
if not os.path.exists(directory):
    os.makedirs(directory)

# df_receitas_limpo.to_csv('./output/gdv_receitas_tratado.csv', sep=',', index=False)
# df_despesas_limpo.to_csv('./output/gdv_despesas_tratado.csv', sep=',', index=False)
df_consolidado.to_csv('./output/gdv_consolidado.csv', sep=',', index=False)
df_combinado.to_csv('./output/gdv_tratado.csv', sep=',', index=False)
